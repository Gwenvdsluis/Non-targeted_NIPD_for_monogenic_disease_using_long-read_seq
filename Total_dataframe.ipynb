# %%
## To do
# Combine the switch_associated.csv with:
# - Cor_phased
# - Depth
# - Sub-PS-tags
# - Flanking nucleotides

# %%
import pandas as pd
import numpy as np

# %%
switches = pd.read_csv("/hpc/umc_laat/gvandersluis/data/Ont_data_nhung/HG002/wf_hvar_ROI/switch_association.csv")
corr_phased = pd.read_csv("/hpc/umc_laat/gvandersluis/data/Ont_data_nhung/HG002/wf_hvar_ROI/cor_phased.vcf.gz", sep="\t", comment='#', names=['CHROM','POS','ID','REF','ALT','QUAL','FILTER','INFO','FORMAT', "sample"])
phase_depth = pd.read_csv("/hpc/umc_laat/gvandersluis/data/Ont_data_nhung/HG002/wf_hvar_ROI/AD_wf_hvar.wf_snp.vcf.gz", sep="\t", comment='#', names=['CHROM','POS','ID','REF','ALT','QUAL','FILTER','INFO','FORMAT', "sample"])
# Out:
# /scratch/47085974/ipykernel_2651991/4154464398.py:1: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   switches = pd.read_csv("/hpc/umc_laat/gvandersluis/data/Ont_data_nhung/HG002/wf_hvar_ROI/switch_association.csv")

# %%
switches
# Out:
#         CHROM       POS ID   REF ALT   QUAL FILTER INFO             FORMAT  \
# 0        chr1    434272  .     A   C   4.07   PASS    F  GT:GQ:DP:AD:AF:PS
# 1        chr1    434286  .     C   G  15.85   PASS    F     GT:GQ:DP:AD:AF
# 2        chr1    434292  .     T   C  20.74   PASS    F  GT:GQ:DP:AD:AF:PS
# 3        chr1    434325  .     C   G  13.74   PASS    F  GT:GQ:DP:AD:AF:PS
# 4        chr1    434364  .     A   G  16.92   PASS    F  GT:GQ:DP:AD:AF:PS
# ...       ...       ... ..   ...  ..    ...    ...  ...                ...
# 3912429  chrY  26117052  .     G   T   2.78   PASS    F  GT:GQ:DP:AD:AF:PS
# 3912430  chrY  26117825  .     C   T   5.52   PASS    F  GT:GQ:DP:AD:AF:PS
# 3912431  chrY  26118416  .     T   A   4.62   PASS    F  GT:GQ:DP:AD:AF:PS
# 3912432  chrY  26119317  .  TGAA   T   3.20   PASS    F  GT:GQ:DP:AD:AF:PS
# 3912433  chrY  26120567  .     G  GC   6.78   PASS    F  GT:GQ:DP:AD:AF:PS
#
#                                 sample   GT  GQ  DP          PS  \
# ...

# %%
corr_phased
# Out:
#         CHROM       POS ID   REF ALT   QUAL FILTER INFO  \
# 0        chr1    434272  .     A   C   4.07   PASS    F
# 1        chr1    434286  .     C   G  15.85   PASS    F
# 2        chr1    434292  .     T   C  20.74   PASS    F
# 3        chr1    434325  .     C   G  13.74   PASS    F
# 4        chr1    434364  .     A   G  16.92   PASS    F
# ...       ...       ... ..   ...  ..    ...    ...  ...
# 3912429  chrY  26117052  .     G   T   2.78   PASS    F
# 3912430  chrY  26117825  .     C   T   5.52   PASS    F
# 3912431  chrY  26118416  .     T   A   4.62   PASS    F
# 3912432  chrY  26119317  .  TGAA   T   3.20   PASS    F
# 3912433  chrY  26120567  .     G  GC   6.78   PASS    F
#
#                                FORMAT                                 sample
# 0        GT:GQ:DP:AD:AF:PS:Cor_phased   0|1:4:33:18,13:0.3939:413640:unknown
# 1           GT:GQ:DP:AD:AF:Cor_phased               1/1:15:33:0,29:0.8788:NA
# ...

# %%
lijstje = ["hoi", "ik", "ben", "Gwen"]
lijstje[:1]

# %%
corr_phased["Corr_phased"] = corr_phased["sample"].str.split(":").str[-1]
corr_phased[["CHROM", "POS", "Corr_phased"]]
# Out:
#         CHROM       POS Corr_phased
# 0        chr1    434272     unknown
# 1        chr1    434286          NA
# 2        chr1    434292     unknown
# 3        chr1    434325     unknown
# 4        chr1    434364     unknown
# ...       ...       ...         ...
# 3912429  chrY  26117052     unknown
# 3912430  chrY  26117825     unknown
# 3912431  chrY  26118416     unknown
# 3912432  chrY  26119317     unknown
# 3912433  chrY  26120567     unknown
#
# [3912434 rows x 3 columns]

# %%
phase_depth
# Out:
#         CHROM       POS ID   REF ALT   QUAL FILTER  \
# 0        chr1    434272  .     A   C   4.07   PASS
# 1        chr1    434286  .     C   G  15.85   PASS
# 2        chr1    434292  .     T   C  20.74   PASS
# 3        chr1    434325  .     C   G  13.74   PASS
# 4        chr1    434364  .     A   G  16.92   PASS
# ...       ...       ... ..   ...  ..    ...    ...
# 3912429  chrY  26117052  .     G   T   2.78   PASS
# 3912430  chrY  26117825  .     C   T   5.52   PASS
# 3912431  chrY  26118416  .     T   A   4.62   PASS
# 3912432  chrY  26119317  .  TGAA   T   3.20   PASS
# 3912433  chrY  26120567  .     G  GC   6.78   PASS
#
#                                                       INFO FORMAT sample
# 0        F;HP1_REF=0;HP1_ALT=0;HP2_REF=1;HP2_ALT=3;UNAS...      .      .
# 1        F;HP1_REF=0;HP1_ALT=0;HP2_REF=0;HP2_ALT=4;UNAS...      .      .
# 2        F;HP1_REF=0;HP1_ALT=0;HP2_REF=1;HP2_ALT=3;UNAS...      .      .
# ...
