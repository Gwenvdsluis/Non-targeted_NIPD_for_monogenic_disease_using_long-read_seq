# %%
#!/usr/bin/env python3

### Imports

import pandas as pd
import numpy as np
import subprocess
import os
import pysam
import matplotlib.pyplot as plt

# %%
### Base table code

def hb_maker(phased_vars_file):
    df_vcf = pd.read_csv(phased_vars_file, sep="\t", names=['CHROM','POS','ID','REF','ALT','QUAL','FILTER','INFO','FORMAT', "sample"])
    df_vcf["GENE"] = df_vcf['INFO'].str.split("|").str[4]
    df_splitted = df_vcf['sample'].str.split(":")
    df_vcf["GT"] = df_splitted.str[0]
    df_vcf["DP"] = df_splitted.str[2]
    df_vcf["PS"] = df_splitted.str[5]
    # Min Quality of 10, this means there is no more than 1/10000 chance of an incorrect base call (>99.9% accuracy)
    # & (pd.to_numeric(df_vcf['DP']) >= 20
    
    phased = df_vcf.loc[df_vcf['PS'].notna(), ['CHROM','POS','QUAL','GENE','GT','DP','PS','REF','ALT']]
    # phased["DP"] = pd.to_numeric(phased["DP"], errors="coerce")
    # phased = phased.sort_values(by="DP")

    grouped = phased.groupby(['PS']).agg({'POS': ['min','max', 'count'],
                                                    'CHROM': 'first',
                                                    'QUAL': 'mean',
                                                    'GENE': 'unique'}).reset_index()
    return grouped


def phased_GOI(regions_file, phased_hps, sample):
    folder = "/hpc/umc_laat/gvandersluis/data/"
    all_vars = f"{folder}Ont_data_nhung/HG00{sample}/SAMPLE_renamed.vcf.gz"
    genes_of_interest = pd.read_csv(regions_file, sep="\t", names=["CHROM","START","END","GENE","INFO","STRAND"])
    goi = genes_of_interest["GENE"].unique()
    genes_of_interest["POSITION"] = genes_of_interest["CHROM"].astype(str)+":"+genes_of_interest["START"].astype(str)+"-"+genes_of_interest["END"].astype(str)
    #print(genes_of_interest)
    # Make sure each GENE entry is a Python list
    phased_hps["GENE"] = phased_hps[("GENE","unique")].apply(lambda x: x.tolist())
    
    phased_hps.columns = ['_'.join([c for c in col if c]).strip() if isinstance(col, tuple) else col for col in phased_hps.columns.values]
    phased_hps.rename(columns={"CHROM_first":"CHROM"}, inplace=True)

    merged = pd.DataFrame(columns=["GENE", "POSITION_ROI", "HB_START", "HB_END", "HB_LENGTH", "PHASED_VARIANTS", "TOTAL_VARIANTS", "REMOVED_VARIANTS", "AVG_QUAL"])
    for idx, item in phased_hps.iterrows():
        reg = item["CHROM"]+":"+str(item["POS_min"])+"-"+str(item["POS_max"])
        # Build the command as a single string
        cmd = f"apptainer exec -B /hpc/:/hpc/ /hpc/umc_laat/gvandersluis/software/bcftools_v1.9-1-deb_cv1.sif bcftools view -r {reg} {all_vars} | wc -l"
        # Run the command
        result = subprocess.run(cmd, shell=True, check=True, capture_output=True, text=True)
        # Get the count as integer
        count = int(result.stdout.strip())        
        #count = subprocess.run(cmd, check=True, capture_output=True)
        for idx, genereg in genes_of_interest.iterrows():
            if item["CHROM"] == genereg["CHROM"] and item["POS_min"] >= genereg["START"] and item["POS_max"] <= genereg["END"]:
                merged.loc[len(merged)] = [genereg["GENE"], genereg["POSITION"], item["POS_min"], item["POS_max"], item["POS_max"]-item["POS_min"]+1, item["POS_count"], count, count-item["POS_count"], item["QUAL_mean"]]


    merged = merged.sort_values(by="GENE")
    






    ### ORIGINAL CODE (only get info for haploblock of interest)
    # # Filter rows where at least one gene in 'unique' is in GOI
    # filtered = phased_hps[phased_hps[("GENE", "unique")].apply(lambda genes: any(g in goi for g in genes))].copy()
    # # Now, inside each row, keep only the genes that match the GOI
    # filtered[("GENE", "unique")] = filtered[("GENE", "unique")].apply(lambda genes: ", ".join([str(g) for g in genes if g in goi]))
    # # Remove sub columns
    # filtered.columns = ['_'.join([c for c in col if c]).strip() if isinstance(col, tuple) else col for col in filtered.columns.values]
    # # Now rename for clarity
    # filtered = filtered.rename(columns={'PS': 'PS',
    #                                     'POS_min': 'POS_START',
    #                                     'POS_max': 'POS_END',
    #                                     'POS_count': 'PHASED_VARIANTS',
    #                                     'CHROM_first': 'chromosome',
    #                                     'QUAL_mean': 'QUAL_MEAN',
    #                                     'GENE_unique': 'GENE'})

    # filtered["HB_LENGTH"] = filtered["POS_END"]-filtered["POS_START"]

    # merged = pd.merge(filtered, genes_of_interest, on="GENE", how="right")[["GENE","POSITION_ROI","HB_START","HB_END","HB_LENGTH","PHASED_VARIANTS"]]
    # int_cols = ["POS_START", "POS_END", "HB_LENGTH", "PHASED_VARIANTS"]

    # for c in int_cols:
    #     merged[c] = pd.to_numeric(merged[c], errors="coerce").astype("Int64")
    # merged = merged.astype(str).replace("<NA>", "NaN")
    return merged

# %%
### Code Calculate Switch Errors

def switch_errors(bs_df, ph_vars, sample, version):
    folder = "/hpc/umc_laat/gvandersluis/data/"    
    BM_vars = f"{folder}Ont_data_nhung/HG00{sample}/HG00{sample}_BM_SSANDT_rn.vcf"
    BM_ROI = f"{folder}Ont_data_nhung/HG00{sample}/{version}_ROI/ROI_eval.tsv"
    open(BM_ROI, "w").close()
    switches_ROI = f"{folder}Ont_data_nhung/HG00{sample}/{version}_ROI/switches_ROI.bed"
    open(switches_ROI, "w").close()

    for idx, region in bs_df.iterrows():
        reg = region["POSITION_ROI"].split(":")[0]+":"+str(region["HB_START"])+"-"+str(region["HB_END"])
        gen = region["GENE"]+"_"+str(region["HB_START"])
        if "NaN" not in reg:
            out_vcf = f"{folder}Ont_data_nhung/HG00{sample}/{version}_ROI/{gen}_BM.vcf"
            cmd = ["apptainer", "exec", "-B", "/hpc/:/hpc/", "/hpc/umc_laat/gvandersluis/software/bcftools_v1.9-1-deb_cv1.sif", "bcftools", "view", "-r", reg, BM_vars, "-Oz", "-o", out_vcf]
            subprocess.run(cmd, check=True)
            indexer = ["apptainer", "exec", "-B", "/hpc/:/hpc/", "/hpc/umc_laat/gvandersluis/software/bcftools_v1.9-1-deb_cv1.sif", "bcftools", "index", "-t", out_vcf]
            subprocess.run(indexer, check=True)
            indexed = out_vcf+".tbi"
            tsv_out = f"{gen}_eval.tsv"
            open(tsv_out, "a+").write("")
            if sum(1 for _ in pysam.VariantFile(out_vcf)) != 0:
                bed_out = f"{folder}Ont_data_nhung/HG00{sample}/{version}_ROI/{gen}_switch.bed"
                cmd2 = ["apptainer", "exec", "-B", "/hpc/:/hpc/", "/hpc/umc_laat/gvandersluis/software/whatshap_v1.sif", "whatshap", "compare","--switch-error-bed",bed_out,"--tsv-pairwise", tsv_out, "--names", f"BENCHMARK,{gen}", out_vcf, ph_vars]
                subprocess.run(cmd2, check=True, capture_output=True)
                if os.path.getsize(BM_ROI) == 0:
                    with open(BM_ROI, "w") as out:
                        with open(tsv_out, "r") as inp:
                            out.write(inp.read())
                else:
                    with open(BM_ROI, "a") as out:
                        with open(tsv_out, "r") as inp:
                            next(inp)
                            out.write(inp.read())
                with open(switches_ROI, "a+") as out_b:
                    with open(bed_out, "r") as inp_b:
                        out_b.write(inp_b.read())
                os.remove(bed_out)
            os.remove(out_vcf)
            os.remove(indexed)
            os.remove(tsv_out)
        print(gen, "\t Done")
    return BM_ROI

# %%
### ALGEMENE FUNCTIE

def main(variants, ph_variants, goi, version, samp):
    ### Make hapbloblocks in ROI
    phased_hb = hb_maker(variants)
    basis_df = phased_GOI(goi, phased_hb, samp)
    
    ### Run Switch Errors
    bm_roi = switch_errors(basis_df, ph_variants, samp, version)

    ### Format the switch error file
    sw_e = pd.read_csv(bm_roi, sep="\t")
    sw_e = sw_e[["dataset_name1","het_variants0","all_switches","all_switch_rate","all_switchflips","all_switchflip_rate","blockwise_hamming_rate"]]
    sw_e["Accuracy"] = (1-sw_e["blockwise_hamming_rate"]).astype(str)+"%"
    sw_e.drop(columns="blockwise_hamming_rate")
    sw_e.rename(columns={"dataset_name1": "GENE_l"}, inplace=True)

    ### Merge Hapoblocks with their switch errors
    basis_df["GENE_l"] = basis_df["GENE"]+"_"+basis_df["HB_START"].astype(str)    
    switch_df = pd.merge(basis_df, sw_e, on="GENE_l", how="left")
    switch_df["difference_het-vars_BM_vs_data"] = abs(switch_df["PHASED_VARIANTS"]-switch_df["het_variants0"])
    switch_df = switch_df.drop(columns="GENE_l")

    ### Write merged dataframe to file
    switch_df.to_csv(f"/hpc/umc_laat/gvandersluis/data/Ont_data_nhung/HG00{samp}/{version}_ROI/final_df.csv", index=False)
    
    return basis_df, switch_df, sw_e

# %%
### File Inputs

# Regions of interest
goi_file = "/hpc/umc_laat/gvandersluis/data/Ref_HG/HG_annotation_ROI.bed"

## VCF Files

# vcf filtered on qual > 40, PASS, and regions of interest
filtered_v = "/hpc/umc_laat/gvandersluis/data/Ont_data_nhung/HG002/filtered_ROI/phased_ROI_nh.vcf"
ph_filtered_v = "/hpc/umc_laat/gvandersluis/data/Ont_data_nhung/HG002/filtered_ROI/phased_ROI.vcf"

# vcf filtered on regions of interest
ununfiltered_v = "/hpc/umc_laat/gvandersluis/data/Ont_data_nhung/HG002/un_unfiltered_ROI/un_unphased_ROI_nh.vcf"
ph_ununfiltered_v = "/hpc/umc_laat/gvandersluis/data/Ont_data_nhung/HG002/un_unfiltered_ROI/phased_ROI.vcf"


# Raw VCF data, only filtered on ROI
ONT = "/hpc/umc_laat/gvandersluis/data/Ont_data_nhung/HG002/unphased_ROI/Sample_un_unfiltered_ROI_nh.vcf.gz"
ph_ONT = "/hpc/umc_laat/gvandersluis/data/Ont_data_nhung/HG002/unphased_ROI/Sample_un_unfiltered_ROI.vcf.gz"

sample = "2"


### RUN CODE
print("VCF filtered on PASS, QUAL >= 40 & ROI")
filtered_Q_ROI = [filtered_v, ph_filtered_v, "filtered"]
basis_f_q_roi, sw_f_q_roi, switch_f_q_roi = main(filtered_Q_ROI[0], filtered_Q_ROI[1], goi_file, filtered_Q_ROI[2], sample)

print("VCF filtered on ROI")
filtered_ROI = [ununfiltered_v, ph_ununfiltered_v ,"un_unfiltered"]
basis_f_roi, sw_f_roi, switch_f_roi = main(filtered_ROI[0], filtered_ROI[1], goi_file, filtered_ROI[2], sample)

print("RAW VCF from ONT filtered on ROI")
RAW_ROI = [ONT, ph_ONT, "unphased"]
raw_f_roi, sw_raw_f_roi, switch_raw_roi = main(RAW_ROI[0], RAW_ROI[1], goi_file, RAW_ROI[2], sample)
# Out:
# VCF filtered on PASS, QUAL >= 40 & ROI
# BRCA1_43183966 	 Done
# BRCA1_42861321 	 Done
# BRCA1_42808235 	 Done
# BRCA1_42607430 	 Done
# BRCA1_43322424 	 Done
# BRCA1_43010006 	 Done
# BRCA2_31865037 	 Done
# BRCA2_32712242 	 Done
# BRCA2_32095084 	 Done
# BRCA2_32180531 	 Done
# BRCA2_32508214 	 Done
# BRCA2_32602810 	 Done
# CFTR_117002433 	 Done
# CFTR_117777011 	 Done
# CRTAP_33204384 	 Done
# CRTAP_32635859 	 Done
# CRTAP_32934214 	 Done
# CYP21A2_32488753 	 Done
# CYP21A2_32000387 	 Done
# CYP21A2_31542190 	 Done
# CYP21A2_32515992 	 Done
# CYP21A2_32185426 	 Done
# HBA1_27803 	 Done
# HBB_4727925 	 Done
# HBB_5273948 	 Done
# HBB_5679844 	 Done
# MUSK_110240520 	 Done
# MUSK_110997014 	 Done
# PEX7_136636685 	 Done
# PEX7_136574402 	 Done
# POLG_88820301 	 Done
# POLG_89660113 	 Done
# SMN1_70485532 	 Done
# SMN1_71217981 	 Done
# SMN1_71016257 	 Done
# SMN1_71067872 	 Done
# SMN1_71317230 	 Done
# TSEN54_75022811 	 Done
# TSEN54_75977471 	 Done
# VCF filtered on ROI
# BRCA1_42607430 	 Done
# BRCA1_43183966 	 Done
# BRCA1_43240781 	 Done
# BRCA2_32712242 	 Done
# BRCA2_32602810 	 Done
# BRCA2_32508214 	 Done
# BRCA2_32180531 	 Done
# BRCA2_31865037 	 Done
# BRCA2_32095084 	 Done
# CFTR_117777011 	 Done
# CFTR_117002433 	 Done
# CRTAP_33204384 	 Done
# CRTAP_32934214 	 Done
# CRTAP_32635859 	 Done
# CYP21A2_31991875 	 Done
# CYP21A2_32185426 	 Done
# CYP21A2_32487383 	 Done
# CYP21A2_32501153 	 Done
# CYP21A2_31542190 	 Done
# HBA1_17889 	 Done
# HBB_4727925 	 Done
# HBB_5273948 	 Done
# MUSK_110239493 	 Done
# MUSK_110997014 	 Done
# PEX7_136636685 	 Done
# PEX7_136574402 	 Done
# POLG_88820301 	 Done
# POLG_89660113 	 Done
# SMN1_70463648 	 Done
# SMN1_70440650 	 Done
# SMN1_70559099 	 Done
# SMN1_70598701 	 Done
# SMN1_70707781 	 Done
# SMN1_70929044 	 Done
# TSEN54_75022811 	 Done
# TSEN54_75977471 	 Done
# RAW VCF from ONT filtered on ROI
# BRCA1_43240781 	 Done
# BRCA1_43183966 	 Done
# BRCA1_42607430 	 Done
# BRCA2_32602810 	 Done
# BRCA2_32712242 	 Done
# BRCA2_31865037 	 Done
# BRCA2_32508214 	 Done
# BRCA2_32180531 	 Done
# BRCA2_32095084 	 Done
# CFTR_117002433 	 Done
# CFTR_117777011 	 Done
# CRTAP_32934214 	 Done
# CRTAP_32635859 	 Done
# CRTAP_33204384 	 Done
# CYP21A2_32185426 	 Done
# CYP21A2_32487383 	 Done
# CYP21A2_32501153 	 Done
# CYP21A2_31991875 	 Done
# CYP21A2_31542190 	 Done
# HBA1_17889 	 Done
# HBB_5273948 	 Done
# HBB_4727925 	 Done
# MUSK_110239493 	 Done
# MUSK_110997014 	 Done
# PEX7_136636685 	 Done
# PEX7_136574402 	 Done
# POLG_88820301 	 Done
# POLG_89660113 	 Done
# SMN1_70440650 	 Done
# SMN1_70559099 	 Done
# SMN1_70598701 	 Done
# SMN1_70707781 	 Done
# SMN1_70929044 	 Done
# TSEN54_75022811 	 Done
# TSEN54_75977471 	 Done

# %%
sw_f_q_roi.tail()
# Out:
#       GENE             POSITION_ROI  HB_START    HB_END  HB_LENGTH  \
# 34    SMN1   chr5:70439486-71439486  71016257  71029957      13701
# 35    SMN1   chr5:70439486-71439486  71067872  71139948      72077
# 36    SMN1   chr5:70439486-71439486  71317230  71437569     120340
# 37  TSEN54  chr17:75020340-76020340  75022811  75870128     847318
# 38  TSEN54  chr17:75020340-76020340  75977471  76019738      42268
#
#     PHASED_VARIANTS  TOTAL_VARIANTS  REMOVED_VARIANTS   AVG_QUAL  \
# 34               22             316               294  46.763636
# 35               14             327               313  48.572857
# 36               65             406               341  54.846308
# 37              544            1758              1214  57.189007
# 38               40             337               297  56.460500
#
#     het_variants0  all_switches  all_switch_rate all_switchflips  \
# 34            NaN           NaN              NaN             NaN
# 35            3.0           0.0              NaN             0/0
# 36           54.0           0.0         0.000000             0/0
# 37          676.0           2.0         0.004739             0/1
# 38           48.0           0.0         0.000000             0/0
#
#     all_switchflip_rate  blockwise_hamming_rate            Accuracy  \
# 34                  NaN                     NaN                 NaN
# 35                  NaN                     NaN                nan%
# 36              0.00000                0.000000              100.0%
# 37              0.00237                0.002364  99.99763593380615%
# 38              0.00000                0.000000              100.0%
#
#     difference_het-vars_BM_vs_data
# 34                             NaN
# 35                            11.0
# 36                            11.0
# 37                           132.0
# 38                             8.0

# %%
df = pd.read_csv("/hpc/umc_laat/gvandersluis/data/Ont_data_nhung/HG002/filtered_ROI/ROI_eval.tsv")
df
#df = sw_f_q_roi[["GENE", "HB_LENGTH", "blockwise_hamming_rate", "all_switches", "het_variants0", "PHASED_VARIANTS", "Accuracy"]]

# %%
# Clean % strings if needed (e.g., "100.0%")
def pct_to_float(x):
    if isinstance(x, str) and x.endswith("%"):
        return float(x.strip("%")) / 100
    return x
    

df["Accuracy"] = df["Accuracy"].apply(pct_to_float)

# -------------------------
# Calculate accuracy metrics
# -------------------------

# Informative ratio (how many phased vs total variants)
df["Informative_Ratio"] = df["PHASED_VARIANTS"] / df["TOTAL_VARIANTS"]

# Combined reliability score
df["Reliability_Score"] = (
    df["Accuracy"] *
    (1 - df["all_switch_rate"].fillna(0)) *
    np.log1p(df["PHASED_VARIANTS"])
)

# Final summary table
qc_table = df[[
    "GENE", "HB_LENGTH", "Accuracy", "all_switch_rate",
    "PHASED_VARIANTS", "Informative_Ratio", "Reliability_Score"
]].sort_values("Reliability_Score", ascending=False)

qc_table
# Out:
#        GENE  HB_LENGTH  Accuracy  all_switch_rate  PHASED_VARIANTS  \
# 24      HBB     352862  1.000000         0.000000             1056
# 21  CYP21A2     300786  1.000000         0.000000              803
# 26     MUSK     715080  1.000000         0.000000              769
# 23      HBB     458428  0.999982         0.003656              783
# 22     HBA1     619150  1.000000         0.000000              614
# 28     PEX7     724900  1.000000         0.000000              603
# 30     POLG     748912  1.000000         0.000000              562
# 37   TSEN54     847318  0.999976         0.004739              544
# 12     CFTR     725444  1.000000         0.000000              416
# 14    CRTAP     424384  1.000000         0.000000              291
# 4     BRCA1     284828  1.000000         0.000000              272
# 27     MUSK     238415  1.000000         0.000000              271
# 16    CRTAP     214616  1.000000         0.000000              209
# 15    CRTAP     258309  1.000000         0.000000              146
# 7     BRCA2     122231  1.000000         0.000000              125
# 13     CFTR     193920  1.000000         0.000000              121
# 19  CYP21A2     364168  1.000000         0.000000               99
# 9     BRCA2     235127  1.000000         0.000000               99
# 18  CYP21A2     136838  1.000000         0.000000               83
# 3     BRCA1     160149  1.000000         0.000000               71
# 6     BRCA2     146894  1.000000         0.000000               69
# 31     POLG     159755  1.000000         0.000000               66
# 36     SMN1     120340  1.000000         0.000000               65
# 25      HBB      28507  1.000000         0.000000               61
# 38   TSEN54      42268  1.000000         0.000000               40
# 1     BRCA1      60292  1.000000         0.000000               13
# 11    BRCA2      62364  1.000000         0.000000                8
# 0     BRCA1      47893  1.000000         0.000000                8
# 5     BRCA1     122597  1.000000         0.000000                7
# 8     BRCA2      28301  1.000000         0.000000                4
# 2     BRCA1       3652  1.000000         0.000000                4
# 10    BRCA2      36724  1.000000         0.000000                4
# 17  CYP21A2       1830       NaN              NaN               13
# 20  CYP21A2      24244       NaN              NaN              153
# 29     PEX7       7841       NaN              NaN                2
# 32     SMN1      51620       NaN              NaN              362
# 33     SMN1          1       NaN              NaN                1
# 34     SMN1      13701       NaN              NaN               22
# 35     SMN1      72077       NaN              NaN               14
#
#     Informative_Ratio  Reliability_Score
# 24           0.523550           6.963190
# 21           0.351730           6.689599
# 26           0.437429           6.646391
# 23           0.489069           6.639921
# 22           0.310258           6.421622
# 28           0.391558           6.403574
# 30           0.389197           6.333280
# 37           0.309443           6.270776
# 12           0.387337           6.033086
# 14           0.401379           5.676754
# 4            0.366083           5.609472
# 27           0.363758           5.605802
# 16           0.285910           5.347108
# 15           0.235864           4.990433
# 7            0.280269           4.836282
# 13           0.236328           4.804021
# 19           0.160714           4.605170
# 9            0.166667           4.605170
# 18           0.187783           4.430817
# 3            0.147303           4.276666
# 6            0.123656           4.248495
# 31           0.088949           4.204693
# 36           0.160099           4.189655
# 25           0.148780           4.127134
# 38           0.118694           3.713572
# 1            0.045296           2.639057
# 11           0.028470           2.197225
# 0            0.025397           2.197225
# 5            0.022876           2.079442
# 8            0.012862           1.609438
# 2            0.014870           1.609438
# 10           0.013201           1.609438
# 17           0.024809                NaN
# 20           0.069831                NaN
# 29           0.007326                NaN
# 32           0.282813                NaN
# 33           0.003759                NaN
# 34           0.069620                NaN
# 35           0.042813                NaN

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,5))
plt.scatter(df["HB_LENGTH"], df["Accuracy"])
plt.xlabel("Phase Block Length (bp)")
plt.ylabel("Accuracy (%) (100 – Hamming Rate)")
plt.title("Accuracy by Block Length")
plt.show()

# %%
plt.figure(figsize=(7,5))
plt.scatter(df["HB_LENGTH"], df["all_switch_rate"])
plt.xlabel("Phase Block Length (bp)")
plt.ylabel("Switch Error %")
plt.title("Switch Errors by Block Length")
plt.show()

# %%
plt.figure(figsize=(7,5))
plt.scatter(df["PHASED_VARIANTS"], df["Accuracy"])
plt.xlabel("Informative Phased Variants")
plt.ylabel("Accuracy")
plt.title("Accuracy vs Informative Phased Variants")
plt.show()

# %%
def classify_block(row):
    A = row["Accuracy"]
    S = row["all_switch_rate"]
    I = row["PHASED_VARIANTS"]

    if A > 0.99 and (S < 0.01 or pd.isna(S)) and I > 20:
        return "Excellent"
    elif A > 0.95 and (S < 0.05 or pd.isna(S)) and I > 10:
        return "Good"
    elif A > 0.80:
        return "Moderate"
    else:
        return "Poor"

qc_table["Quality_Class"] = qc_table.apply(classify_block, axis=1)

qc_table
# Out:
#        GENE  HB_LENGTH  Accuracy  all_switch_rate  PHASED_VARIANTS  \
# 24      HBB     352862  1.000000         0.000000             1056
# 21  CYP21A2     300786  1.000000         0.000000              803
# 26     MUSK     715080  1.000000         0.000000              769
# 23      HBB     458428  0.999982         0.003656              783
# 22     HBA1     619150  1.000000         0.000000              614
# 28     PEX7     724900  1.000000         0.000000              603
# 30     POLG     748912  1.000000         0.000000              562
# 37   TSEN54     847318  0.999976         0.004739              544
# 12     CFTR     725444  1.000000         0.000000              416
# 14    CRTAP     424384  1.000000         0.000000              291
# 4     BRCA1     284828  1.000000         0.000000              272
# 27     MUSK     238415  1.000000         0.000000              271
# 16    CRTAP     214616  1.000000         0.000000              209
# 15    CRTAP     258309  1.000000         0.000000              146
# 7     BRCA2     122231  1.000000         0.000000              125
# 13     CFTR     193920  1.000000         0.000000              121
# 19  CYP21A2     364168  1.000000         0.000000               99
# 9     BRCA2     235127  1.000000         0.000000               99
# 18  CYP21A2     136838  1.000000         0.000000               83
# 3     BRCA1     160149  1.000000         0.000000               71
# 6     BRCA2     146894  1.000000         0.000000               69
# 31     POLG     159755  1.000000         0.000000               66
# 36     SMN1     120340  1.000000         0.000000               65
# 25      HBB      28507  1.000000         0.000000               61
# 38   TSEN54      42268  1.000000         0.000000               40
# 1     BRCA1      60292  1.000000         0.000000               13
# 11    BRCA2      62364  1.000000         0.000000                8
# 0     BRCA1      47893  1.000000         0.000000                8
# 5     BRCA1     122597  1.000000         0.000000                7
# 8     BRCA2      28301  1.000000         0.000000                4
# 2     BRCA1       3652  1.000000         0.000000                4
# 10    BRCA2      36724  1.000000         0.000000                4
# 17  CYP21A2       1830       NaN              NaN               13
# 20  CYP21A2      24244       NaN              NaN              153
# 29     PEX7       7841       NaN              NaN                2
# 32     SMN1      51620       NaN              NaN              362
# 33     SMN1          1       NaN              NaN                1
# 34     SMN1      13701       NaN              NaN               22
# 35     SMN1      72077       NaN              NaN               14
#
#     Informative_Ratio  Reliability_Score Quality_Class
# 24           0.523550           6.963190     Excellent
# 21           0.351730           6.689599     Excellent
# 26           0.437429           6.646391     Excellent
# 23           0.489069           6.639921     Excellent
# 22           0.310258           6.421622     Excellent
# 28           0.391558           6.403574     Excellent
# 30           0.389197           6.333280     Excellent
# 37           0.309443           6.270776     Excellent
# 12           0.387337           6.033086     Excellent
# 14           0.401379           5.676754     Excellent
# 4            0.366083           5.609472     Excellent
# 27           0.363758           5.605802     Excellent
# 16           0.285910           5.347108     Excellent
# 15           0.235864           4.990433     Excellent
# 7            0.280269           4.836282     Excellent
# 13           0.236328           4.804021     Excellent
# 19           0.160714           4.605170     Excellent
# 9            0.166667           4.605170     Excellent
# 18           0.187783           4.430817     Excellent
# 3            0.147303           4.276666     Excellent
# 6            0.123656           4.248495     Excellent
# 31           0.088949           4.204693     Excellent
# 36           0.160099           4.189655     Excellent
# 25           0.148780           4.127134     Excellent
# 38           0.118694           3.713572     Excellent
# 1            0.045296           2.639057          Good
# 11           0.028470           2.197225      Moderate
# 0            0.025397           2.197225      Moderate
# 5            0.022876           2.079442      Moderate
# 8            0.012862           1.609438      Moderate
# 2            0.014870           1.609438      Moderate
# 10           0.013201           1.609438      Moderate
# 17           0.024809                NaN          Poor
# 20           0.069831                NaN          Poor
# 29           0.007326                NaN          Poor
# 32           0.282813                NaN          Poor
# 33           0.003759                NaN          Poor
# 34           0.069620                NaN          Poor
# 35           0.042813                NaN          Poor

# %%
buys = pd.read_csv("/hpc/umc_laat/gvandersluis/buys_const.csv", sep = ";")
buys[["Gene", "phase_set_length", "Accuracy"]]
# Out:
#        Gene          ? Accuracy  checked  incomparable  \
# 0     CRTAP   19364697  100,00%      616             0
# 1      SMN1   69797409  100,00%        8             0
# 2   CYP21A2   26485496   99,75%     1220             7
# 3   CYP21A2   32386097  100,00%        2             0
# 4      PEX7  136574402  100,00%      688             0
# 5      CFTR  116345894  100,00%      828             0
# 6      CFTR  117200818  100,00%        2             0
# 7      MUSK  100185516  100,00%     1168             0
# 8       HBB      66447   99,93%     1535             0
# 9     BRCA2   18171311   58,17%      251             0
# 10     POLG   86443598  100,00%      618             0
# 11     HBA1      10444  100,00%      359             0
# 12    BRCA1   26325044  100,00%      115             0
# 13    BRCA1   43010006  100,00%      342             0
# 14   TSEN54   60207302   99,83%      575             0
# 15    ODAD1   42714529  100,00%      697             0
#
#     n_missing_in_benchmark p_switch  phase_set_end  phase_set_length  \
# 0                      366    0,00%       33647085           1030755
# 1                     1102    0,00%       71418860            782773
# 2                     1116    0,08%       32482836            943812
# 3                        0    0,00%       32386148                51
# 4                      183    0,00%      137405477            831075
# 5                      282    0,00%      118215954           1427435
# 6                        0    0,00%      117200841                23
# 7                      495    0,00%      111298556           1125054
# 8                      775    0,07%        5721749            995462
# 9                      215    0,80%       32894881           1079152
# 10                     291    0,00%       89831025           1024717
# 11                     510    0,00%         648721            617297
# 12                      46    0,00%       42921612            376715
# 13                     219    0,00%       43669479            659473
# 14                     275    0,17%       76020425            998072
# 15                     569    0,00%       48778943            981567
#
#     phase_set_start  switched
# 0          32616330         0
# 1          70636087         0
# 2          31539024         3
# 3          32386097         0
# 4         136574402         0
# 5         116788519         0
# 6         117200818         0
# 7         110173502         0
# 8           4726287         1
# 9          31815729       105
# 10         88806308         0
# 11            31424         0
# 12         42544897         0
# 13         43010006         0
# 14         75022353         1
# 15         47797376         0

# %%
buys = pd.read_csv("/hpc/umc_laat/gvandersluis/buys_const.csv", sep = ";")
buys["Accuracy_num"] = (buys["Accuracy"].str.replace("%", "", regex=False).str.replace(",",".",regex=False).astype(float))
#b_grouped = [b["Accuracy_num"].dropna()for _, b in buys.groupby("Gene")]
buys = (buys[["Gene", "Accuracy_num", "phase_set_length"]])
buys.rename(columns={"Gene":"GENE"}, inplace=True)
const_grouped = buys.groupby(["GENE"])#.agg({"Accuracy_num": ["count", "mean"]})

buys
# Out:
#        GENE  Accuracy_num  phase_set_length
# 0     CRTAP        100.00           1030755
# 1      SMN1        100.00            782773
# 2   CYP21A2         99.75            943812
# 3   CYP21A2        100.00                51
# 4      PEX7        100.00            831075
# 5      CFTR        100.00           1427435
# 6      CFTR        100.00                23
# 7      MUSK        100.00           1125054
# 8       HBB         99.93            995462
# 9     BRCA2         58.17           1079152
# 10     POLG        100.00           1024717
# 11     HBA1        100.00            617297
# 12    BRCA1        100.00            376715
# 13    BRCA1        100.00            659473
# 14   TSEN54         99.83            998072
# 15    ODAD1        100.00            981567

# %%
buys["Method"] = "Constellation"
sw2 = sw_f_q_roi[["GENE", "Accuracy_num"]]
sw2["Method"] = "ONT"

df_long = pd.concat([buys, sw2], ignore_index=True)

df_long
# Out:
# /scratch/43179219/ipykernel_265603/1447291251.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sw2["Method"] = "ONT"
#        GENE  Accuracy_num         Method
# 0     CRTAP    100.000000  Constellation
# 1      SMN1    100.000000  Constellation
# 2   CYP21A2     99.750000  Constellation
# 3   CYP21A2    100.000000  Constellation
# 4      PEX7    100.000000  Constellation
# 5      CFTR    100.000000  Constellation
# 6      CFTR    100.000000  Constellation
# 7      MUSK    100.000000  Constellation
# 8       HBB     99.930000  Constellation
# 9     BRCA2     58.170000  Constellation
# 10     POLG    100.000000  Constellation
# 11     HBA1    100.000000  Constellation
# 12    BRCA1    100.000000  Constellation
# 13    BRCA1    100.000000  Constellation
# 14   TSEN54     99.830000  Constellation
# 15    ODAD1    100.000000  Constellation
# 16    BRCA1    100.000000            ONT
# 17    BRCA1    100.000000            ONT
# 18    BRCA1    100.000000            ONT
# 19    BRCA1    100.000000            ONT
# 20    BRCA1    100.000000            ONT
# 21    BRCA1    100.000000            ONT
# 22    BRCA2    100.000000            ONT
# 23    BRCA2    100.000000            ONT
# 24    BRCA2    100.000000            ONT
# 25    BRCA2    100.000000            ONT
# 26    BRCA2    100.000000            ONT
# 27    BRCA2    100.000000            ONT
# 28     CFTR    100.000000            ONT
# 29     CFTR    100.000000            ONT
# 30    CRTAP    100.000000            ONT
# 31    CRTAP    100.000000            ONT
# 32    CRTAP    100.000000            ONT
# 33  CYP21A2           NaN            ONT
# 34  CYP21A2    100.000000            ONT
# 35  CYP21A2    100.000000            ONT
# 36  CYP21A2           NaN            ONT
# 37  CYP21A2    100.000000            ONT
# 38     HBA1    100.000000            ONT
# 39      HBB     99.998175            ONT
# 40      HBB    100.000000            ONT
# 41      HBB    100.000000            ONT
# 42     MUSK    100.000000            ONT
# 43     MUSK    100.000000            ONT
# 44     PEX7    100.000000            ONT
# 45     PEX7           NaN            ONT
# 46     POLG    100.000000            ONT
# 47     POLG    100.000000            ONT
# 48     SMN1           NaN            ONT
# 49     SMN1           NaN            ONT
# 50     SMN1           NaN            ONT
# 51     SMN1           NaN            ONT
# 52     SMN1    100.000000            ONT
# 53   TSEN54     99.997636            ONT
# 54   TSEN54    100.000000            ONT

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,6))

ax = sns.barplot(
    data=df_long,
    x="GENE",
    y="Accuracy_num",
    hue="Method",
    estimator="mean",
    errorbar="sd"
)

sns.stripplot(
    data=df_long,
    x="GENE",
    y="Accuracy_num",
    hue="Method",
    dodge=True,
    jitter=0.25,
    alpha=0.6,
    linewidth=0,
    palette={"Constellation": "BLACK", "ONT": "BLACK"}   # your colors here

)

# Fix doubled legends (stripplot adds duplicates)
handles, labels = ax.get_legend_handles_labels()
plt.legend(handles[:2], labels[:2])

# Add text labels inside bars
for patch in ax.patches:
    height = patch.get_height()
    ax.text(
        patch.get_x() + patch.get_width() / 2,
        height * 0.5,
        f"{height:.2f}%",
        ha="center", va="center", color="white", fontsize=9, fontweight="bold", rotation=90
    )

plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_melt = newdf.melt(id_vars="GENE",
                  value_vars=["Constellation", "ONT"],
                  var_name="Method",
                  value_name="Accuracy")

plt.figure(figsize=(10,6))
sns.boxplot(data=df_melt, x="GENE", y="Accuracy", hue="Method")

plt.ylabel("Accuracy (%)")
plt.title("Accuracy per Gene")
plt.show()

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /hpc/umc_laat/gvandersluis/software/miniforge3/envs/NIPD/lib/python3.14/site-packages (from seaborn) (2.3.5)
# Requirement already satisfied: pandas>=1.2 in /hpc/umc_laat/gvandersluis/software/miniforge3/envs/NIPD/lib/python3.14/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /hpc/umc_laat/gvandersluis/software/miniforge3/envs/NIPD/lib/python3.14/site-packages (from seaborn) (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in /hpc/umc_laat/gvandersluis/software/miniforge3/envs/NIPD/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /hpc/umc_laat/gvandersluis/software/miniforge3/envs/NIPD/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /hpc/umc_laat/gvandersluis/software/miniforge3/envs/NIPD/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /hpc/umc_laat/gvandersluis/software/miniforge3/envs/NIPD/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /hpc/umc_laat/gvandersluis/software/miniforge3/envs/NIPD/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /hpc/umc_laat/gvandersluis/software/miniforge3/envs/NIPD/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /hpc/umc_laat/gvandersluis/software/miniforge3/envs/NIPD/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /hpc/umc_laat/gvandersluis/software/miniforge3/envs/NIPD/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /hpc/umc_laat/gvandersluis/software/miniforge3/envs/NIPD/lib/python3.14/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /hpc/umc_laat/gvandersluis/software/miniforge3/envs/NIPD/lib/python3.14/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /hpc/umc_laat/gvandersluis/software/miniforge3/envs/NIPD/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
sw_f_q_roi[["GENE", "Accuracy_num"]]
# Out:
#        GENE  Accuracy_num
# 0     BRCA1    100.000000
# 1     BRCA1    100.000000
# 2     BRCA1    100.000000
# 3     BRCA1    100.000000
# 4     BRCA1    100.000000
# 5     BRCA1    100.000000
# 6     BRCA2    100.000000
# 7     BRCA2    100.000000
# 8     BRCA2    100.000000
# 9     BRCA2    100.000000
# 10    BRCA2    100.000000
# 11    BRCA2    100.000000
# 12     CFTR    100.000000
# 13     CFTR    100.000000
# 14    CRTAP    100.000000
# 15    CRTAP    100.000000
# 16    CRTAP    100.000000
# 17  CYP21A2           NaN
# 18  CYP21A2    100.000000
# 19  CYP21A2    100.000000
# 20  CYP21A2           NaN
# 21  CYP21A2    100.000000
# 22     HBA1    100.000000
# 23      HBB     99.998175
# 24      HBB    100.000000
# 25      HBB    100.000000
# 26     MUSK    100.000000
# 27     MUSK    100.000000
# 28     PEX7    100.000000
# 29     PEX7           NaN
# 30     POLG    100.000000
# 31     POLG    100.000000
# 32     SMN1           NaN
# 33     SMN1           NaN
# 34     SMN1           NaN
# 35     SMN1           NaN
# 36     SMN1    100.000000
# 37   TSEN54     99.997636
# 38   TSEN54    100.000000

# %%
sw_f_q_roi["Accuracy_num"] = (
    sw_f_q_roi["Accuracy"]
    .str.replace("%", "", regex=False)
    .astype(float)
)



# group Accuracy values by GENE
grouped = [
    g["Accuracy_num"].dropna()
    for _, g in sw_f_q_roi.groupby("GENE")
]
genes = pd.concat([buys["Gene"], sw_f_q_roi["GENE"]]).unique()

# build grouped lists in SAME order for both datasets
grouped = [sw_f_q_roi.loc[sw_f_q_roi["GENE"] == g, "Accuracy_num"].dropna()
           for g in genes]

b_grouped = [buys.loc[buys["Gene"] == g, "Accuracy_num"].dropna()
             for g in genes]
print(genes)
pos1 = np.arange(1, len(genes)+1) -0.15
pos2 = np.arange(1, len(genes)-1) -0.15


plt.figure()
plt.boxplot(grouped, positions=pos1)
plt.boxplot(b_grouped, positions=pos2)
plt.ylabel("Accuracy (%)")
plt.xticks(rotation=90)
plt.title("Accuracy per Gene")
plt.show()
# Out:
# ['CRTAP' 'SMN1' 'CYP21A2' 'PEX7' 'CFTR' 'MUSK' 'HBB' 'BRCA2' 'POLG' 'HBA1'
#  'BRCA1' 'TSEN54' 'ODAD1']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 29
#      27 plt.figure()
#      28 plt.boxplot(grouped, positions=pos1)
# ---> 29 plt.boxplot(b_grouped, positions=pos2)
#      30 plt.ylabel("Accuracy (%)")
#      31 plt.xticks(rotation=90)
#
# File /hpc/umc_laat/gvandersluis/software/miniforge3/envs/NIPD/lib/python3.14/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File /hpc/umc_laat/gvandersluis/software/miniforge3/envs/NIPD/lib/python3.14/site-packages/matplotlib/_api/deprecation.py:295, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     290     warn_deprecated(
#     291         since, message=f"The {old!r} parameter of {func.__name__}() "
#     292         f"has been renamed {new!r} since Matplotlib {since}; support "
#     293         f"for the old name will be dropped in %(removal)s.")
#     294     kwargs[new] = kwargs.pop(old)
# --> 295 return func(*args, **kwargs)
#
# File /hpc/umc_laat/gvandersluis/software/miniforge3/envs/NIPD/lib/python3.14/site-packages/matplotlib/pyplot.py:3085, in boxplot(x, notch, sym, vert, orientation, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, tick_labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, capwidths, label, data)
#    3051 @_copy_docstring_and_deprecators(Axes.boxplot)
#    3052 def boxplot(
#    3053     x: ArrayLike | Sequence[ArrayLike],
#    (...)   3083     data=None,
#    3084 ) -> dict[str, Any]:
# -> 3085     return gca().boxplot(
#    3086         x,
#    3087         notch=notch,
#    3088         sym=sym,
#    3089         vert=vert,
#    3090         orientation=orientation,
#    3091         whis=whis,
#    3092         positions=positions,
#    3093         widths=widths,
#    3094         patch_artist=patch_artist,
#    3095         bootstrap=bootstrap,
#    3096         usermedians=usermedians,
#    3097         conf_intervals=conf_intervals,
#    3098         meanline=meanline,
#    3099         showmeans=showmeans,
#    3100         showcaps=showcaps,
#    3101         showbox=showbox,
#    3102         showfliers=showfliers,
#    3103         boxprops=boxprops,
#    3104         tick_labels=tick_labels,
#    3105         flierprops=flierprops,
#    3106         medianprops=medianprops,
#    3107         meanprops=meanprops,
#    3108         capprops=capprops,
#    3109         whiskerprops=whiskerprops,
#    3110         manage_ticks=manage_ticks,
#    3111         autorange=autorange,
#    3112         zorder=zorder,
#    3113         capwidths=capwidths,
#    3114         label=label,
#    3115         **({"data": data} if data is not None else {}),
#    3116     )
#
# File /hpc/umc_laat/gvandersluis/software/miniforge3/envs/NIPD/lib/python3.14/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File /hpc/umc_laat/gvandersluis/software/miniforge3/envs/NIPD/lib/python3.14/site-packages/matplotlib/__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File /hpc/umc_laat/gvandersluis/software/miniforge3/envs/NIPD/lib/python3.14/site-packages/matplotlib/_api/deprecation.py:295, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     290     warn_deprecated(
#     291         since, message=f"The {old!r} parameter of {func.__name__}() "
#     292         f"has been renamed {new!r} since Matplotlib {since}; support "
#     293         f"for the old name will be dropped in %(removal)s.")
#     294     kwargs[new] = kwargs.pop(old)
# --> 295 return func(*args, **kwargs)
#
# File /hpc/umc_laat/gvandersluis/software/miniforge3/envs/NIPD/lib/python3.14/site-packages/matplotlib/axes/_axes.py:4232, in Axes.boxplot(self, x, notch, sym, vert, orientation, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, tick_labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, capwidths, label)
#    4229                     if ci[1] is not None:
#    4230                         stats['cihi'] = ci[1]
# -> 4232 artists = self.bxp(bxpstats, positions=positions, widths=widths,
#    4233                    vert=vert, patch_artist=patch_artist,
#    4234                    shownotches=notch, showmeans=showmeans,
#    4235                    showcaps=showcaps, showbox=showbox,
#    4236                    boxprops=boxprops, flierprops=flierprops,
#    4237                    medianprops=medianprops, meanprops=meanprops,
#    4238                    meanline=meanline, showfliers=showfliers,
#    4239                    capprops=capprops, whiskerprops=whiskerprops,
#    4240                    manage_ticks=manage_ticks, zorder=zorder,
#    4241                    capwidths=capwidths, label=label,
#    4242                    orientation=orientation)
#    4243 return artists
#
# File /hpc/umc_laat/gvandersluis/software/miniforge3/envs/NIPD/lib/python3.14/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File /hpc/umc_laat/gvandersluis/software/miniforge3/envs/NIPD/lib/python3.14/site-packages/matplotlib/axes/_axes.py:4485, in Axes.bxp(self, bxpstats, positions, widths, vert, orientation, patch_artist, shownotches, showmeans, showcaps, showbox, showfliers, boxprops, whiskerprops, flierprops, medianprops, capprops, meanprops, meanline, manage_ticks, zorder, capwidths, label)
#    4483     positions = list(range(1, N + 1))
#    4484 elif len(positions) != N:
# -> 4485     raise ValueError(datashape_message.format("positions"))
#    4487 positions = np.array(positions)
#    4488 if len(positions) > 0 and not all(isinstance(p, Real) for p in positions):
#
# ValueError: List of boxplot statistics and `positions` values must have same the length

# %%
## NIET GOED MEER

final_df = pd.merge(switch_df, switch_df_uf[["POSITION_ROI","PHASED_VARIANTS"]], how="left", on="POSITION_ROI")
final_df["FILTERED_VARIANTS"] = (pd.to_numeric(final_df["PHASED_VARIANTS_y"], errors="coerce") - pd.to_numeric(final_df["PHASED_VARIANTS_x"], errors="coerce"))
final_df = final_df[["GENE", "POSITION_ROI", "HB_START", "HB_END", "HB_LENGTH", "PHASED_VARIANTS_x", "FILTERED_VARIANTS", "all_switches"]]
final_df.rename(columns={"PHASED_VARIANTS_x": "PHASED_VARIANTS"}, inplace=True)

int_cols = ["HB_START", "HB_END", "HB_LENGTH", "PHASED_VARIANTS", "FILTERED_VARIANTS", "all_switches"]

for c in int_cols:
    final_df[c] = pd.to_numeric(final_df[c], errors="coerce").astype("Int64")
final_df = final_df.astype(str).replace("<NA>", "NaN")

final_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 3
#       1 ## NIET GOED MEER
# ----> 3 final_df = pd.merge(switch_df, switch_df_uf[["POSITION_ROI","PHASED_VARIANTS"]], how="left", on="POSITION_ROI")
#       4 final_df["FILTERED_VARIANTS"] = (pd.to_numeric(final_df["PHASED_VARIANTS_y"], errors="coerce") - pd.to_numeric(final_df["PHASED_VARIANTS_x"], errors="coerce"))
#       5 final_df = final_df[["GENE", "POSITION_ROI", "HB_START", "HB_END", "HB_LENGTH", "PHASED_VARIANTS_x", "FILTERED_VARIANTS", "all_switches"]]
#
# NameError: name 'switch_df' is not defined

# %%
pd.concat([switch_df_uf,switch_ONT]).drop_duplicates(keep=False)
# Out:
#        GENE            POSITION_ROI  HB_START    HB_END  HB_LENGTH  \
# 17  CYP21A2  chr6:31540309-32540309  32501153  32540235      39083
# 28     SMN1  chr5:70439486-71439486  70463648  70538381      74734
# 29     SMN1  chr5:70439486-71439486  70440650  70553669     113020
# 16  CYP21A2  chr6:31540309-32540309  32501153  32540235      39083
# 28     SMN1  chr5:70439486-71439486  70440650  70553669     113020
#
#     PHASED_VARIANTS  TOTAL_VARIANTS  REMOVED_VARIANTS   AVG_QUAL  \
# 17             1472            3251              1779  19.056848
# 28                5            1342              1337  17.664000
# 29              861            1436               575  34.538792
# 16             1471            3251              1780  19.058770
# 28              866            1436               570  34.441363
#
#     het_variants0  all_switches  all_switch_rate all_switchflips  \
# 17            NaN           NaN              NaN             NaN
# 28            1.0           0.0              NaN             0/0
# 29            2.0           0.0              NaN             0/0
# 16            NaN           NaN              NaN             NaN
# 28            2.0           0.0              NaN             0/0
#
#     all_switchflip_rate Accuracy  difference_het-vars_BM_vs_data
# 17                  NaN      NaN                             NaN
# 28                  NaN     nan%                             4.0
# 29                  NaN     nan%                           859.0
# 16                  NaN      NaN                             NaN
# 28                  NaN     nan%                           864.0

# %%
### Interesting Code Lines

# find how many phased variant per selected region
bcftools view -r 'chr3:32934214-33148829' phased_ROI.vcf.gz | grep -E '0\|1|1\|1|1\|0|0\|0' | wc

bcftools view -H  -i 'FORMAT/PS="."' -r 'chr17:75022811-75870128' phased_ROI.vcf.gz | wc
bcftools view -H  -i 'FORMAT/GT!~"/"'  -r 'chr17:75022811-75870128' phased_ROI.vcf.gz | wc
bcftools view -H  -i 'FORMAT/PS!="."' -r 'chr17:75022811-75870128' phased_ROI.vcf.gz | wc
bcftools view -H  -i 'FORMAT/GT~"/"'  -r 'chr17:75022811-75870128' phased_ROI.vcf.gz | wc
# Out:
#   Cell In[23], line 4
#     bcftools view -r 'chr3:32934214-33148829' phased_ROI.vcf.gz | grep -E '0\|1|1\|1|1\|0|0\|0' | wc
#              ^
# SyntaxError: invalid syntax
